# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/content/NYPD_Shooting_Incident_Data__Historic__20240530.csv")

# %%
df.head()
# Out:
#    INCIDENT_KEY  OCCUR_DATE OCCUR_TIME       BORO LOC_OF_OCCUR_DESC  PRECINCT  \
# 0     244608249  05/05/2022   00:10:00  MANHATTAN            INSIDE      14.0
# 1     247542571  07/04/2022   22:20:00      BRONX           OUTSIDE      48.0
# 2      84967535  05/27/2012   19:35:00     QUEENS               NaN     103.0
# 3     202853370  09/24/2019   21:00:00      BRONX               NaN      42.0
# 4      27078636  02/25/2007   21:00:00   BROOKLYN               NaN      83.0
#
#    JURISDICTION_CODE LOC_CLASSFCTN_DESC LOCATION_DESC STATISTICAL_MURDER_FLAG  \
# 0                0.0         COMMERCIAL   VIDEO STORE                    True
# 1                0.0             STREET        (null)                    True
# 2                0.0                NaN           NaN                   False
# 3                0.0                NaN           NaN                   False
# 4                0.0                NaN           NaN                   False
#
# ...

# %%
df.tail()
# Out:
#        INCIDENT_KEY  OCCUR_DATE OCCUR_TIME       BORO LOC_OF_OCCUR_DESC  \
# 28557     265354835  03/19/2023   23:48:00      BRONX            INSIDE
# 28558     272968931  08/16/2023   02:46:00      BRONX           OUTSIDE
# 28559     270489846  06/27/2023   12:27:00      BRONX            INSIDE
# 28560     271021661  07/08/2023   11:27:00     QUEENS           OUTSIDE
# 28561     271818283  07/24/2023   23:38:00  MANHATTAN           OUTSIDE
#
#        PRECINCT  JURISDICTION_CODE LOC_CLASSFCTN_DESC  \
# 28557        47                0.0         COMMERCIAL
# 28558        41                0.0             STREET
# 28559        41                0.0           DWELLING
# 28560       102                0.0             STREET
# 28561        28                2.0            HOUSING
#
#                    LOCATION_DESC  STATISTICAL_MURDER_FLAG  ... PERP_SEX  \
# 28557             GROCERY/BODEGA                     True  ...        M
# ...

# %%
df.dropna()
# Out:
#        INCIDENT_KEY  OCCUR_DATE OCCUR_TIME       BORO LOC_OF_OCCUR_DESC  \
# 0         244608249  05/05/2022   00:10:00  MANHATTAN            INSIDE
# 1         247542571  07/04/2022   22:20:00      BRONX           OUTSIDE
# 72        254911480  11/30/2022   21:15:00      BRONX           OUTSIDE
# 78        249623757  08/15/2022   18:21:00     QUEENS           OUTSIDE
# 98        243433246  04/10/2022   17:00:00      BRONX           OUTSIDE
# ...             ...         ...        ...        ...               ...
# 28557     265354835  03/19/2023   23:48:00      BRONX            INSIDE
# 28558     272968931  08/16/2023   02:46:00      BRONX           OUTSIDE
# 28559     270489846  06/27/2023   12:27:00      BRONX            INSIDE
# 28560     271021661  07/08/2023   11:27:00     QUEENS           OUTSIDE
# 28561     271818283  07/24/2023   23:38:00  MANHATTAN           OUTSIDE
#
#        PRECINCT  JURISDICTION_CODE LOC_CLASSFCTN_DESC  \
# ...

# %%
df.describe()
# Out:
#        INCIDENT_KEY      PRECINCT  JURISDICTION_CODE    X_COORD_CD  \
# count  2.856200e+04  28562.000000       28560.000000  2.856200e+04
# mean   1.274058e+08     65.496009           0.321884  1.009424e+06
# std    7.804340e+07     27.342643           0.733035  1.830111e+04
# min    9.953245e+06      1.000000           0.000000  9.149281e+05
# 25%    6.543991e+07     44.000000           0.000000  1.000068e+06
# 50%    9.271125e+07     67.000000           0.000000  1.007772e+06
# 75%    2.031320e+08     81.000000           0.000000  1.016807e+06
# max    2.797581e+08    123.000000           2.000000  1.066815e+06
#
#           Y_COORD_CD      Latitude     Longitude
# count   28562.000000  28503.000000  28503.000000
# mean   208380.075755     40.738570    -73.909099
# std     31917.509528      0.087611      0.065967
# min    125756.718750     40.511586    -74.249303
# 25%    182912.000000     40.668648    -73.942917
# 50%    194901.390625     40.701467    -73.915068
# ...

# %%
df.isnull()
# Out:
#        INCIDENT_KEY  OCCUR_DATE  OCCUR_TIME   BORO  LOC_OF_OCCUR_DESC  \
# 0             False       False       False  False              False
# 1             False       False       False  False              False
# 2             False       False       False  False               True
# 3             False       False       False  False               True
# 4             False       False       False  False               True
# ...             ...         ...         ...    ...                ...
# 28557         False       False       False  False              False
# 28558         False       False       False  False              False
# 28559         False       False       False  False              False
# 28560         False       False       False  False              False
# 28561         False       False       False  False              False
#
#        PRECINCT  JURISDICTION_CODE  LOC_CLASSFCTN_DESC  LOCATION_DESC  \
# ...

# %%
df.dropna()
# Out:
#        INCIDENT_KEY  OCCUR_DATE OCCUR_TIME       BORO LOC_OF_OCCUR_DESC  \
# 0         244608249  05/05/2022   00:10:00  MANHATTAN            INSIDE
# 1         247542571  07/04/2022   22:20:00      BRONX           OUTSIDE
# 72        254911480  11/30/2022   21:15:00      BRONX           OUTSIDE
# 78        249623757  08/15/2022   18:21:00     QUEENS           OUTSIDE
# 98        243433246  04/10/2022   17:00:00      BRONX           OUTSIDE
# ...             ...         ...        ...        ...               ...
# 19657     260362155  12/21/2022   14:22:00   BROOKLYN           OUTSIDE
# 19662     244663902  05/05/2022   09:15:00   BROOKLYN           OUTSIDE
# 19665     242551329  03/23/2022   23:48:00   BROOKLYN            INSIDE
# 19669     247542571  07/04/2022   22:20:00      BRONX           OUTSIDE
# 19687     248109545  07/16/2022   00:35:00      BRONX           OUTSIDE
#
#        PRECINCT  JURISDICTION_CODE LOC_CLASSFCTN_DESC  \
# ...

# %%
df
# Out:
#        INCIDENT_KEY  OCCUR_DATE OCCUR_TIME       BORO LOC_OF_OCCUR_DESC  \
# 0         244608249  05/05/2022   00:10:00  MANHATTAN            INSIDE
# 1         247542571  07/04/2022   22:20:00      BRONX           OUTSIDE
# 2          84967535  05/27/2012   19:35:00     QUEENS               NaN
# 3         202853370  09/24/2019   21:00:00      BRONX               NaN
# 4          27078636  02/25/2007   21:00:00   BROOKLYN               NaN
# ...             ...         ...        ...        ...               ...
# 19687     248109545  07/16/2022   00:35:00      BRONX           OUTSIDE
# 19688      85639531  07/07/2012   00:55:00   BROOKLYN               NaN
# 19689      87349059  10/22/2012   01:04:00   BROOKLYN               NaN
# 19690      28966096  05/10/2007   19:39:00     QUEENS               NaN
# 19691      80951465           0        NaN        NaN               NaN
#
#        PRECINCT  JURISDICTION_CODE LOC_CLASSFCTN_DESC  \
# ...
